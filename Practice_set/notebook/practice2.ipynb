# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

# %%
df= pd.read_csv(r"C:\Users\Acer\Desktop\Data_Science_Projects\Practice_set\data\practice2.csv")
df.head()
# Out:
#            id   Date  bedrooms  bathrooms  living area  lot area  \
# 0  6762810635  42491         4       2.50         2920      4000
# 1  6762810998  42491         5       2.75         2910      9480
# 2  6762812605  42491         4       2.50         3310     42998
# 3  6762812919  42491         3       2.00         2710      4500
# 4  6762813105  42491         3       2.50         2600      4750
#
#    number of floors  waterfront present  number of views  \
# 0               1.5                   0                0
# 1               1.5                   0                0
# 2               2.0                   0                0
# 3               1.5                   0                0
# 4               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1909                0       122004
# 1                       3  ...        1939                0       122004
# ...

# %%
#data cleaning
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# bedrooms                                 0
# bathrooms                                0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df=df.dropna()
df.head()
# Out:
#            id   Date  bedrooms  bathrooms  living area  lot area  \
# 0  6762810635  42491         4       2.50         2920      4000
# 1  6762810998  42491         5       2.75         2910      9480
# 2  6762812605  42491         4       2.50         3310     42998
# 3  6762812919  42491         3       2.00         2710      4500
# 4  6762813105  42491         3       2.50         2600      4750
#
#    number of floors  waterfront present  number of views  \
# 0               1.5                   0                0
# 1               1.5                   0                0
# 2               2.0                   0                0
# 3               1.5                   0                0
# 4               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1909                0       122004
# 1                       3  ...        1939                0       122004
# ...

# %% [markdown]
# #Exploratory Data Analysis(EDA)

# %%
df.describe()
# Out:
#                  id          Date      bedrooms     bathrooms   living area  \
# count  1.461900e+04  14619.000000  14619.000000  14619.000000  14619.000000
# mean   6.762821e+09  42604.546412      3.379233      2.129557   2098.156851
# std    6.237162e+03     67.343747      0.938655      0.769955    928.218740
# min    6.762810e+09  42491.000000      1.000000      0.500000    370.000000
# 25%    6.762815e+09  42546.000000      3.000000      1.750000   1440.000000
# 50%    6.762821e+09  42600.000000      3.000000      2.250000   1930.000000
# 75%    6.762826e+09  42662.000000      4.000000      2.500000   2570.000000
# max    6.762832e+09  42734.000000     33.000000      8.000000  13540.000000
#
#            lot area  number of floors  waterfront present  number of views  \
# count  1.461900e+04      14619.000000        14619.000000     14619.000000
# mean   1.509369e+04          1.502326            0.007661         0.232848
# ...

# %%
#price distribution
df['Price'].hist()
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.title("House Price Distribution")
plt.show()

# %%
#feature selection
features=['living area','bedrooms','bathrooms']
X=df[features] #input
y=df['Price'] #output

# %% [markdown]
# # Train-Validation Split
# Training data- model learns ,
# Validation data-model is tested

# %%
X_train,X_valid,y_train,y_valid=train_test_split(X,y,random_state=42)

# %%
#Train the model-Random Forest
model=RandomForestRegressor(
    random_state=42,
    n_estimators=100 
)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
#make predictions
predictions=model.predict(X_valid)

# %%
#Model Evaluation(mae)
mae=mean_absolute_error(y_valid,predictions)
print("Mean Absolute Error : ",mae)
# Out:
# Mean Absolute Error :  175962.35860009308

# %%
model2=RandomForestRegressor(
    random_state=42,
    n_estimators=200,
    max_leaf_nodes=50
)
model2.fit(X_train,y_train)
predictions=model2.predict(X_valid)
mae=mean_absolute_error(y_valid,predictions)
print("Mean Absolute Error : ",mae)
# Out:
# Mean Absolute Error :  160731.3811104355

# %% [markdown]
# # Why mae changes ?
# Because we changed how complex and stable the model is.
# # n_estimators-
# How many trees are there.
# --> more trees-lower mae.
# --> less trees-higher mae.
# # max_leaf_nodes-
# How simple or complex each tree is .
# --> more max_leaf_nodes - complex tree - overfitting
# --> less max_leaf_nodes - simple tree - underfitting
#
# # When these change,predictions change,so error(MAE) changes.
#
# # Real life example
# --> one doctor-more chance of mistake
# --> 100 doctor - better average opinion
#
# But :
# --> Doctors with very little knowledge-underfitting
# --> Doctors who memorizes every case-overfitting
#
# # Best mae
# Balanced knowledge + Enough doctors
